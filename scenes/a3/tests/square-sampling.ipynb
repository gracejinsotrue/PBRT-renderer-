# %%
# %matplotlib notebook
import math
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
A = cv2.imread('emitter-sample.exr', cv2.IMREAD_UNCHANGED)[:,:,::-1]

# %%
plt.figure()
plt.plot(A[:,:,0].flatten(), A[:,:,2].flatten(), '.', ms=1)
plt.xlabel('z')
plt.ylabel('x');
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.hist(A[:,:,0].flatten(), 30)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (array([1354., 1293., 1336., 1357., 1339., 1373., 1286., 1309., 1292.,
#         1387., 1378., 1324., 1380., 1311., 1281., 1374., 1329., 1328.,
#         1406., 1306., 1323., 1291., 1290., 1248., 1399., 1361., 1331.,
#         1399., 1284., 1331.]),
#  array([0.        , 0.0333329 , 0.0666658 , 0.0999987 , 0.1333316 ,
#         0.1666645 , 0.1999974 , 0.2333303 , 0.2666632 , 0.2999961 ,
#         0.333329  , 0.3666619 , 0.3999948 , 0.4333277 , 0.4666606 ,
#         0.4999935 , 0.5333264 , 0.56665933, 0.5999922 , 0.6333251 ,
#         0.666658  , 0.6999909 , 0.7333238 , 0.7666567 , 0.7999896 ,
#         0.8333225 , 0.8666554 , 0.8999883 , 0.9333212 , 0.9666541 ,
#         0.999987  ], dtype=float32),
#  <BarContainer object of 30 artists>)

# %%
A[171,57]
# Out:
# array([0., 0., 0.], dtype=float32)

# %%
A = cv2.imread('emitter-sample-bug1.exr', cv2.IMREAD_UNCHANGED)[:,:,::-1]

# %%
plt.figure()
plt.plot(A[:,:,2].flatten(), A[:,:,0].flatten(), '.', ms=1)
plt.xlabel('z')
plt.ylabel('x');
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
A = cv2.imread('emitter-sample-bug2.exr', cv2.IMREAD_UNCHANGED)[:,:,::-1]

# %%
plt.figure()
plt.plot(A[:,:,2].flatten(), A[:,:,0].flatten(), '.', ms=1)
plt.xlabel('z')
plt.ylabel('x');
# Out:
# <img src="data:image/png;base64,..." width="640">
