# %%
import os
os.environ["OPENCV_IO_ENABLE_OPENEXR"] = "1"

# %%
# %matplotlib notebook
import math
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
A = cv2.imread('emitter-sample.exr', cv2.IMREAD_UNCHANGED)[:,:,::-1]

# %%
plt.figure()
plt.plot(A[:,:,0].flatten(), A[:,:,2].flatten(), '.', ms=1)
plt.xlabel('z')
plt.ylabel('x');
# Out:
# <div id='27106444-803e-4aee-bcfe-c2ceddba571e'></div>

# %%
plt.figure()
plt.hist(A[:,:,0].flatten(), 30)
# Out:
# <div id='42905978-d2c7-454f-b395-a424c4f87e01'></div>
# (array([1279., 1275., 1361., 1302., 1317., 1370., 1383., 1371., 1292.,
#         1351., 1300., 1375., 1316., 1331., 1355., 1336., 1374., 1266.,
#         1323., 1341., 1325., 1370., 1311., 1309., 1327., 1345., 1346.,
#         1369., 1349., 1331.]),
#  array([0.        , 0.03333062, 0.06666123, 0.09999184, 0.13332246,
#         0.16665308, 0.19998369, 0.23331431, 0.26664492, 0.29997554,
#         0.33330616, 0.36663678, 0.39996737, 0.43329799, 0.46662861,
#         0.49995923, 0.53328985, 0.56662047, 0.59995109, 0.63328171,
#         0.66661233, 0.69994295, 0.73327357, 0.76660419, 0.79993474,
#         0.83326536, 0.86659598, 0.8999266 , 0.93325722, 0.96658784,
#         0.99991846]),
#  <BarContainer object of 30 artists>)

# %%
A[171,57]
# Out:
# array([0., 0., 0.], dtype=float32)

# %% [markdown]
# what the heck is bug1.exr??

# %%
# A = cv2.imread('emitter-sample-bug1.exr', cv2.IMREAD_UNCHANGED)[:,:,::-1]
A = cv2.imread('emitter-sample-bug1.exr', cv2.IMREAD_UNCHANGED)[:,:,::-1]
# Out:
# [ WARN:0@0.313] global loadsave.cpp:278 findDecoder imread_('emitter-sample-bug1.exr'): can't open/read file: check file path/integrity
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 A = cv2.imread('emitter-sample-bug1.exr', cv2.IMREAD_UNCHANGED)[:,:,::-1]
#
# TypeError: 'NoneType' object is not subscriptable

# %%
plt.figure()
plt.plot(A[:,:,2].flatten(), A[:,:,0].flatten(), '.', ms=1)
plt.xlabel('z')
plt.ylabel('x');
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
A = cv2.imread('emitter-sample-bug2.exr', cv2.IMREAD_UNCHANGED)[:,:,::-1]

# %%
plt.figure()
plt.plot(A[:,:,2].flatten(), A[:,:,0].flatten(), '.', ms=1)
plt.xlabel('z')
plt.ylabel('x');
# Out:
# <img src="data:image/png;base64,..." width="640">
